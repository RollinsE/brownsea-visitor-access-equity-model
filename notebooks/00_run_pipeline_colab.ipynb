# %% [markdown]
# # Brownsea pipeline run notebook
# This notebook is the supported Colab entrypoint for the professional pipeline.

# %%
# !pip install -r requirements/colab.txt

# %%
import os
os.environ['ORS_API_KEY'] = 'YOUR_KEY_HERE'

# %%
# !python cli.py --mode colab --output-dir /content/outputs
