# %% [markdown]
# # View saved Brownsea outputs
#
# Run the pipeline in a separate cell or terminal first. This notebook only displays files already written by the pipeline.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path('/content/brownsea_pipeline') if Path('/content/brownsea_pipeline').exists() else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from src.notebook_viewer import display_saved_outputs

# %%
# For Colab/Drive runs, update this if your output root differs.
OUTPUT_ROOT = '/content/drive/MyDrive/brownsea/outputs'
display_saved_outputs(OUTPUT_ROOT, release_name='latest', max_items=12)

# %%
# Or view the latest build instead of the promoted release:
# display_saved_outputs(OUTPUT_ROOT, max_items=12)
